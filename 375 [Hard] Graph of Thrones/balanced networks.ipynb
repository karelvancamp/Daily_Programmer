Theon and Yara Greyjoy -- Arya Stark
Theon and Yara Greyjoy -- Bran Stark
Theon and Yara Greyjoy -- The Lords of the North and the Vale
Theon and Yara Greyjoy -- Littlefinger
Theon and Yara Greyjoy -- Cersei Lannister
Theon and Yara Greyjoy -- Jaime Lannister
Theon and Yara Greyjoy -- Euron Greyjoy
Sansa Stark ++ Arya Stark
Sansa Stark ++ Bran Stark
Sansa Stark ++ The Lords of the North and the Vale
Sansa Stark ++ Littlefinger
Sansa Stark -- Cersei Lannister
Sansa Stark -- Jaime Lannister
Sansa Stark -- Euron Greyjoy
Arya Stark ++ Bran Stark
Arya Stark ++ The Lords of the North and the Vale
Arya Stark ++ Littlefinger
Arya Stark -- Cersei Lannister
Arya Stark -- Jaime Lannister
Arya Stark -- Euron Greyjoy
Bran Stark ++ The Lords of the North and the Vale
Bran Stark -- Littlefinger
Bran Stark -- Cersei Lannister
Bran Stark -- Jaime Lannister
Bran Stark -- Euron Greyjoy
The Lords of the North and the Vale ++ Littlefinger
The Lords of the North and the Vale -- Cersei Lannister
The Lords of the North and the Vale -- Jaime Lannister
The Lords of the North and the Vale -- Euron Greyjoy
Littlefinger -- Cersei Lannister
Littlefinger -- Jaime Lannister
Littlefinger -- Euron Greyjoy
Cersei Lannister ++ Jaime Lannister
Cersei Lannister ++ Euron Greyjoy
Jaime Lannister ++ Euron Greyjoy"""

# %%
def translate(inx):
    i = inx.replace(' ','_').replace('“','').replace('”','').split('\n')
    n,e = map(int,i[0].split('_'))
    P,M = [],[]
    for x in i[1:]:
        i = x.find('_++_')
        if i != -1:
            P.append({x[:i],x[i+4:]}) 
        else:
            i = x.find('_--_')
            M.append({x[:i],x[i+4:]})
    return n,P,M,set(y for x in P+M for y in x)

for x in S:
    print(f"    MERGE ({x}:Person {{name:'{x}'}})")
for x,y in P:
    print(f"    MERGE ({x})-[:FRIEND]->({y})")
for x,y in M:
    print(f"    MERGE ({x})-[:ENEMY]->({y})")
# Out:
#     MERGE (Sandor_the_Hound_Clegane:Person {name:'Sandor_the_Hound_Clegane'})
#     MERGE (Bran_Stark:Person {name:'Bran_Stark'})
#     MERGE (Euron_Greyjoy:Person {name:'Euron_Greyjoy'})
#     MERGE (Beric_Dondarrion:Person {name:'Beric_Dondarrion'})
#     MERGE (Jaime_Lannister:Person {name:'Jaime_Lannister'})
#     MERGE (Varys:Person {name:'Varys'})
#     MERGE (Daenerys_Targaryen:Person {name:'Daenerys_Targaryen'})
#     MERGE (Sansa_Stark:Person {name:'Sansa_Stark'})
#     MERGE (The_Lords_of_the_North_and_the_Vale:Person {name:'The_Lords_of_the_North_and_the_Vale'})
#     MERGE (Littlefinger:Person {name:'Littlefinger'})
#     MERGE (Jon_Snow:Person {name:'Jon_Snow'})
#     MERGE (Jorah_Mormont:Person {name:'Jorah_Mormont'})
#     MERGE (Theon_and_Yara_Greyjoy:Person {name:'Theon_and_Yara_Greyjoy'})
#     MERGE (Tyrion_Lannister:Person {name:'Tyrion_Lannister'})
#     MERGE (Cersei_Lannister:Person {name:'Cersei_Lannister'})
#     MERGE (Arya_Stark:Person {name:'Arya_Stark'})
#     MERGE (Daenerys_Targaryen)-[:FRIEND]->(Jon_Snow)
#     MERGE (Tyrion_Lannister)-[:FRIEND]->(Daenerys_Targaryen)
#     MERGE (Varys)-[:FRIEND]->(Daenerys_Targaryen)
#     MERGE (Daenerys_Targaryen)-[:FRIEND]->(Jorah_Mormont)
#     MERGE (Daenerys_Targaryen)-[:FRIEND]->(Beric_Dondarrion)
#     MERGE (Sandor_the_Hound_Clegane)-[:FRIEND]->(Daenerys_Targaryen)
#     MERGE (Theon_and_Yara_Greyjoy)-[:FRIEND]->(Daenerys_Targaryen)
#     MERGE (Tyrion_Lannister)-[:FRIEND]->(Jon_Snow)
#     MERGE (Varys)-[:FRIEND]->(Jon_Snow)
#     MERGE (Jon_Snow)-[:FRIEND]->(Jorah_Mormont)
#     MERGE (Jon_Snow)-[:FRIEND]->(Beric_Dondarrion)
#     MERGE (Sandor_the_Hound_Clegane)-[:FRIEND]->(Jon_Snow)
#     MERGE (Tyrion_Lannister)-[:FRIEND]->(Varys)
#     MERGE (Tyrion_Lannister)-[:FRIEND]->(Jorah_Mormont)
#     MERGE (Tyrion_Lannister)-[:FRIEND]->(Beric_Dondarrion)
#     MERGE (Sandor_the_Hound_Clegane)-[:FRIEND]->(Tyrion_Lannister)
#     MERGE (Theon_and_Yara_Greyjoy)-[:FRIEND]->(Tyrion_Lannister)
#     MERGE (Varys)-[:FRIEND]->(Jorah_Mormont)
#     MERGE (Varys)-[:FRIEND]->(Beric_Dondarrion)
#     MERGE (Sandor_the_Hound_Clegane)-[:FRIEND]->(Varys)
#     MERGE (Theon_and_Yara_Greyjoy)-[:FRIEND]->(Varys)
#     MERGE (Beric_Dondarrion)-[:FRIEND]->(Jorah_Mormont)
#     MERGE (Sandor_the_Hound_Clegane)-[:FRIEND]->(Jorah_Mormont)
#     MERGE (Theon_and_Yara_Greyjoy)-[:FRIEND]->(Jorah_Mormont)
#     MERGE (Sandor_the_Hound_Clegane)-[:FRIEND]->(Beric_Dondarrion)
#     MERGE (Theon_and_Yara_Greyjoy)-[:FRIEND]->(Beric_Dondarrion)
#     MERGE (Sandor_the_Hound_Clegane)-[:FRIEND]->(Theon_and_Yara_Greyjoy)
#     MERGE (Sansa_Stark)-[:FRIEND]->(Arya_Stark)
#     MERGE (Sansa_Stark)-[:FRIEND]->(Bran_Stark)
#     MERGE (Sansa_Stark)-[:FRIEND]->(The_Lords_of_the_North_and_the_Vale)
#     MERGE (Sansa_Stark)-[:FRIEND]->(Littlefinger)
#     MERGE (Bran_Stark)-[:FRIEND]->(Arya_Stark)
#     MERGE (The_Lords_of_the_North_and_the_Vale)-[:FRIEND]->(Arya_Stark)
#     MERGE (Littlefinger)-[:FRIEND]->(Arya_Stark)
#     MERGE (Bran_Stark)-[:FRIEND]->(The_Lords_of_the_North_and_the_Vale)
#     MERGE (The_Lords_of_the_North_and_the_Vale)-[:FRIEND]->(Littlefinger)
#     MERGE (Jaime_Lannister)-[:FRIEND]->(Cersei_Lannister)
#     MERGE (Euron_Greyjoy)-[:FRIEND]->(Cersei_Lannister)
#     MERGE (Jaime_Lannister)-[:FRIEND]->(Euron_Greyjoy)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Daenerys_Targaryen)
#     MERGE (Daenerys_Targaryen)-[:ENEMY]->(Arya_Stark)
#     MERGE (Bran_Stark)-[:ENEMY]->(Daenerys_Targaryen)
#     MERGE (The_Lords_of_the_North_and_the_Vale)-[:ENEMY]->(Daenerys_Targaryen)
#     MERGE (Littlefinger)-[:ENEMY]->(Daenerys_Targaryen)
#     MERGE (Cersei_Lannister)-[:ENEMY]->(Daenerys_Targaryen)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(Daenerys_Targaryen)
#     MERGE (Euron_Greyjoy)-[:ENEMY]->(Daenerys_Targaryen)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(Jon_Snow)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Jon_Snow)
#     MERGE (Jon_Snow)-[:ENEMY]->(Arya_Stark)
#     MERGE (Bran_Stark)-[:ENEMY]->(Jon_Snow)
#     MERGE (The_Lords_of_the_North_and_the_Vale)-[:ENEMY]->(Jon_Snow)
#     MERGE (Littlefinger)-[:ENEMY]->(Jon_Snow)
#     MERGE (Cersei_Lannister)-[:ENEMY]->(Jon_Snow)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(Jon_Snow)
#     MERGE (Euron_Greyjoy)-[:ENEMY]->(Jon_Snow)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Tyrion_Lannister)
#     MERGE (Tyrion_Lannister)-[:ENEMY]->(Arya_Stark)
#     MERGE (Tyrion_Lannister)-[:ENEMY]->(Bran_Stark)
#     MERGE (Tyrion_Lannister)-[:ENEMY]->(The_Lords_of_the_North_and_the_Vale)
#     MERGE (Tyrion_Lannister)-[:ENEMY]->(Littlefinger)
#     MERGE (Tyrion_Lannister)-[:ENEMY]->(Cersei_Lannister)
#     MERGE (Tyrion_Lannister)-[:ENEMY]->(Jaime_Lannister)
#     MERGE (Tyrion_Lannister)-[:ENEMY]->(Euron_Greyjoy)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Varys)
#     MERGE (Varys)-[:ENEMY]->(Arya_Stark)
#     MERGE (Bran_Stark)-[:ENEMY]->(Varys)
#     MERGE (The_Lords_of_the_North_and_the_Vale)-[:ENEMY]->(Varys)
#     MERGE (Varys)-[:ENEMY]->(Littlefinger)
#     MERGE (Varys)-[:ENEMY]->(Cersei_Lannister)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(Varys)
#     MERGE (Euron_Greyjoy)-[:ENEMY]->(Varys)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Jorah_Mormont)
#     MERGE (Arya_Stark)-[:ENEMY]->(Jorah_Mormont)
#     MERGE (Bran_Stark)-[:ENEMY]->(Jorah_Mormont)
#     MERGE (The_Lords_of_the_North_and_the_Vale)-[:ENEMY]->(Jorah_Mormont)
#     MERGE (Littlefinger)-[:ENEMY]->(Jorah_Mormont)
#     MERGE (Cersei_Lannister)-[:ENEMY]->(Jorah_Mormont)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(Jorah_Mormont)
#     MERGE (Euron_Greyjoy)-[:ENEMY]->(Jorah_Mormont)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Beric_Dondarrion)
#     MERGE (Arya_Stark)-[:ENEMY]->(Beric_Dondarrion)
#     MERGE (Bran_Stark)-[:ENEMY]->(Beric_Dondarrion)
#     MERGE (The_Lords_of_the_North_and_the_Vale)-[:ENEMY]->(Beric_Dondarrion)
#     MERGE (Littlefinger)-[:ENEMY]->(Beric_Dondarrion)
#     MERGE (Cersei_Lannister)-[:ENEMY]->(Beric_Dondarrion)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(Beric_Dondarrion)
#     MERGE (Euron_Greyjoy)-[:ENEMY]->(Beric_Dondarrion)
#     MERGE (Sandor_the_Hound_Clegane)-[:ENEMY]->(Sansa_Stark)
#     MERGE (Sandor_the_Hound_Clegane)-[:ENEMY]->(Arya_Stark)
#     MERGE (Sandor_the_Hound_Clegane)-[:ENEMY]->(Bran_Stark)
#     MERGE (Sandor_the_Hound_Clegane)-[:ENEMY]->(The_Lords_of_the_North_and_the_Vale)
#     MERGE (Sandor_the_Hound_Clegane)-[:ENEMY]->(Littlefinger)
#     MERGE (Sandor_the_Hound_Clegane)-[:ENEMY]->(Cersei_Lannister)
#     MERGE (Sandor_the_Hound_Clegane)-[:ENEMY]->(Jaime_Lannister)
#     MERGE (Sandor_the_Hound_Clegane)-[:ENEMY]->(Euron_Greyjoy)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(Sansa_Stark)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(Arya_Stark)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(Bran_Stark)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(The_Lords_of_the_North_and_the_Vale)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(Littlefinger)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(Cersei_Lannister)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(Jaime_Lannister)
#     MERGE (Theon_and_Yara_Greyjoy)-[:ENEMY]->(Euron_Greyjoy)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Cersei_Lannister)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Jaime_Lannister)
#     MERGE (Sansa_Stark)-[:ENEMY]->(Euron_Greyjoy)
#     MERGE (Cersei_Lannister)-[:ENEMY]->(Arya_Stark)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(Arya_Stark)
#     MERGE (Euron_Greyjoy)-[:ENEMY]->(Arya_Stark)
#     MERGE (Bran_Stark)-[:ENEMY]->(Littlefinger)
#     MERGE (Bran_Stark)-[:ENEMY]->(Cersei_Lannister)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(Bran_Stark)
#     MERGE (Bran_Stark)-[:ENEMY]->(Euron_Greyjoy)
#     MERGE (The_Lords_of_the_North_and_the_Vale)-[:ENEMY]->(Cersei_Lannister)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(The_Lords_of_the_North_and_the_Vale)
#     MERGE (Euron_Greyjoy)-[:ENEMY]->(The_Lords_of_the_North_and_the_Vale)
#     MERGE (Littlefinger)-[:ENEMY]->(Cersei_Lannister)
#     MERGE (Jaime_Lannister)-[:ENEMY]->(Littlefinger)
#     MERGE (Euron_Greyjoy)-[:ENEMY]->(Littlefinger)

# %%
n,P,M,S = translate(inx)

# %% [markdown]
# ### Neo4j
#
#     CALL algo.unionFind.stream('Person', 'FRIEND', {write:true,  partitionProperty:"Partition"})
#     YIELD nodeId,setId
#     with algo.getNodeById(nodeId) as n , setId as p
#     set n.Partition = p;
#
#     MATCH (n:Person)
#     MERGE (c:Team {name: n.Partition});
#
#     match (n:Person),(c:Team)
#     where n.Partition = c.name
#     merge (n)-[:Member]->(c);
#
#     match (n:Team)<-[:Member]-(p:Person)-[:FRIEND]-(pp:Person)-[:Member]->(nn:Team)
#     merge (n)-[:FRIEND]->(nn);
#
#     match (n:Team)<-[:Member]-(p:Person)-[:ENEMY]-(pp:Person)-[:Member]->(nn:Team)
#     merge (n)-[:ENEMY]->(nn);
#
#     MATCH (:Person)-[r:ENEMY]-(:Person)
#     DELETE r;
#
#     MATCH (:Person)-[r:FRIEND]-(:Person)
#     DELETE r;
#
#     match (n:Team) return (n);
